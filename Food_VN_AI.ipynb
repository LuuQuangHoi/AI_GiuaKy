# %% [markdown]
# <a href="https://colab.research.google.com/github/LuuQuangHoi/AI_GiuaKy/blob/main/Food_VN_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nhận diện 10 món ăn Việt Nam
# Lưu Quang Hội - 20146124

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/AI_Train/Data_Input/Data_Food_VN/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('BanhCuon'):
    output = 1.0
  if file.startswith('BanhGio'):
    output = 2.0
  if file.startswith('BanhMi'):
    output = 3.0
  if file.startswith('BanhPia'):
    output = 4.0
  if file.startswith('BunBoHue'):
    output = 5.0
  if file.startswith('BunRieu'):
    output = 6.0
  if file.startswith('CaKhoTo'):
    output = 7.0
  if file.startswith('ChaoLong'):
    output = 8.0
  if file.startswith('ComTam'):
    output = 9.0
  if file.startswith('NemChua'):
    output = 10.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (1553, 100, 100, 3) (1553,)

# %%
photos = photos.astype('float32')/255.0
print(photos.shape)
# Out:
# (1553, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)

(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (931, 100, 100, 3)
# (931,)
# (311, 100, 100, 3)
# (311,)
# (311, 100, 100, 3)
# (311,)

# %%
image_test=58
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Mon này là: ', trainY[image_test])
# Out:
# Mon này là:  10.0

# %%
for i in range(30):  # 30 hình ảnh
  plt.subplot(5,6,i+1) # 6 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
#one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (931, 11)
# (311, 11)
# (311, 11)

# %%
batch_size=32
epochs = 50
classes = 11

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'tanh', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'tanh' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))




# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'tanh'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 2,863,691
# Trainable params: 2,863,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=50,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 32s 1s/step - loss: 2.1954 - accuracy: 0.2073 - val_loss: 1.9624 - val_accuracy: 0.2926
# Epoch 2/50
# 30/30 [==============================] - 30s 1s/step - loss: 1.7913 - accuracy: 0.3781 - val_loss: 1.8199 - val_accuracy: 0.3794
# Epoch 3/50
# 30/30 [==============================] - 29s 987ms/step - loss: 1.5699 - accuracy: 0.4758 - val_loss: 1.6557 - val_accuracy: 0.4180
# Epoch 4/50
# 30/30 [==============================] - 29s 980ms/step - loss: 1.2390 - accuracy: 0.6058 - val_loss: 1.5988 - val_accuracy: 0.4695
# Epoch 5/50
# 30/30 [==============================] - 30s 993ms/step - loss: 0.9427 - accuracy: 0.7132 - val_loss: 1.5137 - val_accuracy: 0.4887
# Epoch 6/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.7432 - accuracy: 0.7852 - val_loss: 1.5168 - val_accuracy: 0.5145
# Epoch 7/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.4969 - accuracy: 0.8829 - val_loss: 1.5263 - val_accuracy: 0.5177
# Epoch 8/50
# 30/30 [==============================] - 29s 967ms/step - loss: 0.3421 - accuracy: 0.9409 - val_loss: 1.4677 - val_accuracy: 0.5402
# Epoch 9/50
# 30/30 [==============================] - 29s 988ms/step - loss: 0.2047 - accuracy: 0.9871 - val_loss: 1.4578 - val_accuracy: 0.5595
# Epoch 10/50
# 30/30 [==============================] - 29s 980ms/step - loss: 0.1212 - accuracy: 0.9968 - val_loss: 1.4979 - val_accuracy: 0.5691
# Epoch 11/50
# 30/30 [==============================] - 29s 980ms/step - loss: 0.0769 - accuracy: 0.9989 - val_loss: 1.5072 - val_accuracy: 0.5723
# Epoch 12/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 1.5263 - val_accuracy: 0.5691
# Epoch 13/50
# 30/30 [==============================] - 29s 965ms/step - loss: 0.0436 - accuracy: 1.0000 - val_loss: 1.5554 - val_accuracy: 0.5563
# Epoch 14/50
# 30/30 [==============================] - 30s 1s/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.5680 - val_accuracy: 0.5595
# Epoch 15/50
# 30/30 [==============================] - 29s 984ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 1.6046 - val_accuracy: 0.5595
# Epoch 16/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 1.6061 - val_accuracy: 0.5563
# Epoch 17/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.6122 - val_accuracy: 0.5788
# Epoch 18/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 1.6247 - val_accuracy: 0.5498
# Epoch 19/50
# 30/30 [==============================] - 29s 970ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 1.6353 - val_accuracy: 0.5659
# Epoch 20/50
# 30/30 [==============================] - 29s 967ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.6249 - val_accuracy: 0.5691
# Epoch 21/50
# 30/30 [==============================] - 29s 973ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.6470 - val_accuracy: 0.5691
# Epoch 22/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.6524 - val_accuracy: 0.5691
# Epoch 23/50
# 30/30 [==============================] - 29s 985ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.6570 - val_accuracy: 0.5659
# Epoch 24/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.6674 - val_accuracy: 0.5691
# Epoch 25/50
# 30/30 [==============================] - 29s 975ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.6835 - val_accuracy: 0.5659
# Epoch 26/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6900 - val_accuracy: 0.5563
# Epoch 27/50
# 30/30 [==============================] - 30s 993ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.6958 - val_accuracy: 0.5498
# Epoch 28/50
# 30/30 [==============================] - 30s 996ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.6995 - val_accuracy: 0.5627
# Epoch 29/50
# 30/30 [==============================] - 30s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.7079 - val_accuracy: 0.5531
# Epoch 30/50
# 30/30 [==============================] - 30s 982ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.7175 - val_accuracy: 0.5531
# Epoch 31/50
# 30/30 [==============================] - 29s 965ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7216 - val_accuracy: 0.5563
# Epoch 32/50
# 30/30 [==============================] - 29s 970ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.7303 - val_accuracy: 0.5595
# Epoch 33/50
# 30/30 [==============================] - 29s 975ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.7281 - val_accuracy: 0.5498
# Epoch 34/50
# 30/30 [==============================] - 29s 976ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.7403 - val_accuracy: 0.5531
# Epoch 35/50
# 30/30 [==============================] - 29s 970ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7497 - val_accuracy: 0.5531
# Epoch 36/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.7527 - val_accuracy: 0.5595
# Epoch 37/50
# 30/30 [==============================] - 29s 972ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7623 - val_accuracy: 0.5531
# Epoch 38/50
# 30/30 [==============================] - 29s 987ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.7554 - val_accuracy: 0.5498
# Epoch 39/50
# 30/30 [==============================] - 29s 972ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7702 - val_accuracy: 0.5531
# Epoch 40/50
# 30/30 [==============================] - 29s 983ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.7772 - val_accuracy: 0.5531
# Epoch 41/50
# 30/30 [==============================] - 29s 984ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.7831 - val_accuracy: 0.5531
# Epoch 42/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.7826 - val_accuracy: 0.5466
# Epoch 43/50
# 30/30 [==============================] - 28s 944ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.7877 - val_accuracy: 0.5531
# Epoch 44/50
# 30/30 [==============================] - 29s 969ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.7940 - val_accuracy: 0.5498
# Epoch 45/50
# 30/30 [==============================] - 29s 967ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.8008 - val_accuracy: 0.5466
# Epoch 46/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.8036 - val_accuracy: 0.5466
# Epoch 47/50
# 30/30 [==============================] - 28s 951ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.8137 - val_accuracy: 0.5498
# Epoch 48/50
# 30/30 [==============================] - 31s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.8125 - val_accuracy: 0.5498
# Epoch 49/50
# 30/30 [==============================] - 29s 974ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.8160 - val_accuracy: 0.5434
# Epoch 50/50
# 30/30 [==============================] - 29s 966ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.8213 - val_accuracy: 0.5466
# 1524.787050485611

# %%
model.save('/content/drive/MyDrive/AI_Train/Model_Train/Model_FoodVN.h5')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'BanhCuon', 2:'BanhGio',3:'BanhMi',4:'BanhPia',5:'BunBoHue',6:'BunRieu',7:'CaKhoTo',8:'ChaoLong',9:'ComTam',10:'NemChua'}  
#test
filePath = '/content/drive/MyDrive/AI_Train/Data_Input/Data_Food_VN/CaKhoTo (98).jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predicted:  CaKhoTo

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=100, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 4/4 [==============================] - 1s 316ms/step
# Accuracy: 52.0 %
