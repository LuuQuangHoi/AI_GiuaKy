# %% [markdown]
# <a href="https://colab.research.google.com/github/LuuQuangHoi/AI_GiuaKy/blob/main/Face_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nhận diện khuôn mặt bạn trong lớp
# Lưu Quang Hội - 20146124

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/AI_Train/Data_Input/Face data/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('Dien'):
    output = 1.0
  if file.startswith('Hoi'):
    output = 2.0
  if file.startswith('Trung'):
    output = 3.0
  if file.startswith('quyen'):
    output = 4.0
  if file.startswith('Toan'):
    output = 5.0
  if file.startswith('Luan'):
    output = 6.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# save('/content/drive/MyDrive/anh/hoa/hoa_photos.npy',photos)
# save('/content/drive/MyDrive/anh/hoa/hoa_labels.npy',labels)
# Out:
# (359, 100, 100, 3) (359,)

# %%
photos = photos.astype('float32')/255.0
print(photos.shape)
# Out:
# (359, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (215, 100, 100, 3)
# (215,)
# (72, 100, 100, 3)
# (72,)
# (72, 100, 100, 3)
# (72,)

# %%
image_test=80
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hinh này là: ', trainY[image_test])
# Out:
# Hinh này là:  6.0

# %%
for i in range(25):  # 25 hình ảnh
  plt.subplot(5,5,i+1) # 5 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
 #one hot enccoding giatri mau tung diem anh tu thap phan duoi dang 10 bit
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (215, 7)
# (72, 7)
# (72, 7)

# %%
batch_size=32
epochs=50
classes = 7

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# Bộ 4 VGG
model.add(Conv2D(256,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))

# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(512, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     

model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 100, 100, 32)      896
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 100, 100, 32)      0
#
#  max_pooling2d_4 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 256)       295168
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 13, 13, 256)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 512)               6423040
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 512)               0
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 6,815,047
# Trainable params: 6,815,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 10s 1s/step - loss: 1.7402 - accuracy: 0.3767 - val_loss: 1.0007 - val_accuracy: 0.6528
# Epoch 2/50
# 7/7 [==============================] - 7s 943ms/step - loss: 0.6128 - accuracy: 0.7814 - val_loss: 0.2006 - val_accuracy: 0.8611
# Epoch 3/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.0885 - accuracy: 0.9674 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 4/50
# 7/7 [==============================] - 7s 949ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9861
# Epoch 5/50
# 7/7 [==============================] - 9s 1s/step - loss: 4.1924e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9861
# Epoch 6/50
# 7/7 [==============================] - 7s 943ms/step - loss: 1.3398e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9861
# Epoch 7/50
# 7/7 [==============================] - 8s 1s/step - loss: 6.2420e-05 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9861
# Epoch 8/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.6267e-06 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9861
# Epoch 9/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.8167e-07 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 0.9861
# Epoch 10/50
# 7/7 [==============================] - 7s 1s/step - loss: 2.4396e-07 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9861
# Epoch 11/50
# 7/7 [==============================] - 8s 1s/step - loss: 2.2178e-07 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9861
# Epoch 12/50
# 7/7 [==============================] - 8s 1s/step - loss: 2.1458e-07 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9861
# Epoch 13/50
# 7/7 [==============================] - 10s 1s/step - loss: 2.1291e-07 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9861
# Epoch 14/50
# 7/7 [==============================] - 7s 956ms/step - loss: 2.0737e-07 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9861
# Epoch 15/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0681e-07 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9861
# Epoch 16/50
# 7/7 [==============================] - 7s 937ms/step - loss: 2.0349e-07 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9861
# Epoch 17/50
# 7/7 [==============================] - 9s 1s/step - loss: 2.0127e-07 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9861
# Epoch 18/50
# 7/7 [==============================] - 7s 996ms/step - loss: 1.9794e-07 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9861
# Epoch 19/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.9739e-07 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9861
# Epoch 20/50
# 7/7 [==============================] - 7s 1s/step - loss: 1.9406e-07 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9861
# Epoch 21/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.9129e-07 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9861
# Epoch 22/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.8852e-07 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9861
# Epoch 23/50
# 7/7 [==============================] - 7s 982ms/step - loss: 1.8519e-07 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9861
# Epoch 24/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.8353e-07 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9861
# Epoch 25/50
# 7/7 [==============================] - 7s 951ms/step - loss: 1.8075e-07 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9861
# Epoch 26/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.7798e-07 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9861
# Epoch 27/50
# 7/7 [==============================] - 6s 933ms/step - loss: 1.7466e-07 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9861
# Epoch 28/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.7410e-07 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9861
# Epoch 29/50
# 7/7 [==============================] - 7s 953ms/step - loss: 1.7077e-07 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9861
# Epoch 30/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.6856e-07 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9861
# Epoch 31/50
# 7/7 [==============================] - 7s 950ms/step - loss: 1.6634e-07 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9861
# Epoch 32/50
# 7/7 [==============================] - 11s 2s/step - loss: 1.6357e-07 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9861
# Epoch 33/50
# 7/7 [==============================] - 7s 945ms/step - loss: 1.6246e-07 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9861
# Epoch 34/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.6135e-07 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9861
# Epoch 35/50
# 7/7 [==============================] - 7s 955ms/step - loss: 1.5802e-07 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9861
# Epoch 36/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.5691e-07 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9861
# Epoch 37/50
# 7/7 [==============================] - 6s 931ms/step - loss: 1.5414e-07 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9861
# Epoch 38/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.5248e-07 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9861
# Epoch 39/50
# 7/7 [==============================] - 6s 941ms/step - loss: 1.4970e-07 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9861
# Epoch 40/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.4749e-07 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9861
# Epoch 41/50
# 7/7 [==============================] - 7s 965ms/step - loss: 1.4416e-07 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9861
# Epoch 42/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.4361e-07 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9861
# Epoch 43/50
# 7/7 [==============================] - 7s 944ms/step - loss: 1.4083e-07 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9861
# Epoch 44/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.3806e-07 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9861
# Epoch 45/50
# 7/7 [==============================] - 6s 936ms/step - loss: 1.3695e-07 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9861
# Epoch 46/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.3473e-07 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9861
# Epoch 47/50
# 7/7 [==============================] - 7s 1s/step - loss: 1.3418e-07 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9861
# Epoch 48/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.3085e-07 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9861
# Epoch 49/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.2863e-07 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9861
# Epoch 50/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.2697e-07 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9861
# 442.8080427646637

# %%
model.save('/content/drive/MyDrive/AI_Train/Model_Train/Model_Face_Recognition.h5')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'Dien', 2:'Hoi',3:'Trung',4:'quyen',5:'Toan',6:'Luan'}  
#test
filePath = '/content/drive/MyDrive/AI_Train/Data_Input/Hoi.jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Predicted:  Hoi

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=72, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 3/3 [==============================] - 1s 163ms/step
# Accuracy: 100.0 %
